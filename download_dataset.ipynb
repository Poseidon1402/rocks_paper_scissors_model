# %% [markdown]
# ## Download datasets from Kaggle

# %%
import kagglehub

path = kagglehub.dataset_download("andrewmvd/face-mask-detection")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/andrewmvd/face-mask-detection?dataset_version_number=1...
# 100%|██████████| 398M/398M [11:14<00:00, 619kB/s]
# Extracting files...
# Path to dataset files: C:\Users\Aina\.cache\kagglehub\datasets\andrewmvd\face-mask-detection\versions\1

# %% [markdown]
# ## Move datasets to project directory

# %%
import shutil
import os

# Define source and destination directories
source_dir = path  # The directory where the dataset was downloaded
dest_dir = os.path.join(os.getcwd(), 'datasets')  # Project's data directory

# Create destination directory if it doesn't exist
os.makedirs(dest_dir, exist_ok=True)
# Move files from source to destination
for item in os.listdir(source_dir):
    s = os.path.join(source_dir, item)
    d = os.path.join(dest_dir, item)
    if os.path.isdir(s):
        shutil.move(s, d)
    else:
        shutil.move(s, d)
print(f"Datasets moved to {dest_dir}")
# Out:
# Datasets moved to d:\AI\Computer vision\mask_prediction\datasets
